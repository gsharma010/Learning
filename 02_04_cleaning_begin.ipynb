# %% [markdown]
# ## Python statistics essential training - 02_04_cleaning

# %% [markdown]
# Standard imports

# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
billboard = pd.read_csv("billboard.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas/_libs/parsers.c:14858)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas/_libs/parsers.c:17119)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas/_libs/parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas/_libs/parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa1 in position 2: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-a4491d577e4a> in <module>
# ----> 1 billboard = pd.read_csv("billboard.csv")
#
# ...

# %%
## utf error can be solved by specifying the encoding, ISO-8859 text is called as latin-1
# !file billboard.csv
# Out:
# billboard.csv: ISO-8859 text, with very long lines

# %%
billboard = pd.read_csv("billboard.csv", encoding='latin-1')

# %%
billboard.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
# ...

# %%
billboard.columns
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
# ...

# %%
pp.plot(billboard.loc[0,'x1st.week':'x76th.week'])

# %%
pp.plot(range(1,77),billboard.loc[0,'x1st.week':'x76th.week'])

# %%
for index, row in billboard.iterrows():
    pp.plot(range(1,77), row['x1st.week':'x76th.week'], color='C0', alpha = 0.1)
    ## alpha is for transparency

# %%
for index, row in billboard.iterrows():
    pp.plot(row['x1st.week':'x76th.week'], color='C0', alpha = 0.1)
    ## alpha is for transparency

# %%
for index, row in billboard.iterrows():
    pp.plot(range(1,77), row['x1st.week':'x76th.week'], color='C1', alpha = 0.1)
    ## alpha is for transparency

# %%
for index, row in billboard.iterrows():
    pp.plot(range(1,77), row['x1st.week':'x76th.week'], color='C1', alpha = 0.2)
    ## alpha is for transparency

# %%
for index, row in billboard.iterrows():
    pp.plot(range(1,77), row['x1st.week':'x76th.week'], color='C1', alpha = 0.8)
    ## alpha is for transparency

# %%
for index, row in billboard.iterrows():
    pp.plot(range(1,77), row['x1st.week':'x76th.week'], color='C2', alpha = 0.8)
    ## alpha is for transparency
